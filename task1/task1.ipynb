# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv')
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
selected_data = df[['Age','LearnCode','YearsCode','DevType','LanguageHaveWorkedWith',
                    'LanguageWantToWorkWith','WebframeHaveWorkedWith','WebframeWantToWorkWith',
                   'ToolsTechHaveWorkedWith','ToolsTechHaveWorkedWith']]
selected_data.head(50)
# Out:
#                    Age                                          LearnCode  \
# 0      18-24 years old                                                NaN
# 1      25-34 years old  Books / Physical media;Colleague;Friend or fam...
# 2      45-54 years old  Books / Physical media;Colleague;On the job tr...
# 3      25-34 years old  Colleague;Friend or family member;Other online...
# 4      25-34 years old  Books / Physical media;Online Courses or Certi...
# 5      35-44 years old  Books / Physical media;Colleague;Online Course...
# 6      35-44 years old  Friend or family member;Online Courses or Cert...
# 7      25-34 years old  Books / Physical media;Online Courses or Certi...
# 8      45-54 years old  Online Courses or Certification;On the job tra...
# 9      25-34 years old  Books / Physical media;Online Courses or Certi...
# 10     25-34 years old  Books / Physical media;Friend or family member...
# 11     25-34 years old  Online Courses or Certification;Other online r...
# ...

# %%
selected_data.set_index('DevType')
# Out:
#                                                      Age  \
# DevType
# NaN                                      18-24 years old
# Senior Executive (C-Suite, VP, etc.)     25-34 years old
# Developer, back-end                      45-54 years old
# Developer, front-end                     25-34 years old
# Developer, full-stack                    25-34 years old
# ...                                                  ...
# Developer, front-end                     25-34 years old
# Developer, back-end                      18-24 years old
# NaN                                    Prefer not to say
# System administrator                  Under 18 years old
# Developer, full-stack                    35-44 years old
#
#                                                                               LearnCode  \
# DevType
# NaN                                                                                 NaN
# ...

# %%
filter = (selected_data['LanguageHaveWorkedWith'].str.contains('Python')) & (selected_data['Age']=='Under 18 years old')
selected_data.loc[filter]
# Out:
#                       Age                                          LearnCode  \
# 52     Under 18 years old  Colleague;Friend or family member;School (i.e....
# 53     Under 18 years old  Friend or family member;School (i.e., Universi...
# 57     Under 18 years old  Books / Physical media;Friend or family member...
# 62     Under 18 years old  Online Courses or Certification;Other online r...
# 94     Under 18 years old  Books / Physical media;Other online resources ...
# ...                   ...                                                ...
# 89060  Under 18 years old  Friend or family member;Other online resources...
# 89063  Under 18 years old  Hackathons (virtual or in-person);Online Cours...
# 89065  Under 18 years old  Books / Physical media;Colleague;Online Course...
# 89134  Under 18 years old                                                NaN
# 89182  Under 18 years old  Online Courses or Certification;Other online r...
#
#       YearsCode               DevType  \
# ...

# %%
selected_data.sort_values(by=['YearsCode','LearnCode'])
# Out:
#                       Age               LearnCode YearsCode  \
# 4221   Under 18 years old  Books / Physical media         1
# 9910      18-24 years old  Books / Physical media         1
# 15958  Under 18 years old  Books / Physical media         1
# 28141     35-44 years old  Books / Physical media         1
# 30263  Under 18 years old  Books / Physical media         1
# ...                   ...                     ...       ...
# 88828     25-34 years old                     NaN       NaN
# 88830     18-24 years old                     NaN       NaN
# 89028     45-54 years old                     NaN       NaN
# 89134  Under 18 years old                     NaN       NaN
# 89159   Prefer not to say                     NaN       NaN
#
#                              DevType  \
# 4221             Academic researcher
# 9910                             NaN
# 15958            Academic researcher
# 28141  Cloud infrastructure engineer
# 30263                            NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\nanops.py:785, in nanmedian(values, axis, skipna, mask)
#     784 try:
# --> 785     values = values.astype("f8")
#     786 except ValueError as err:
#     787     # e.g. "could not convert string to float: 'a'"
#
# ValueError: could not convert string to float: 'Less than 1 year'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 selected_data['YearsCode'].median()
#
# File C:\Python311\Lib\site-packages\pandas\core\series.py:6231, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6223 @doc(make_doc("median", ndim=1))
#    6224 def median(
#    6225     self,
#    (...)
#    6229     **kwargs,
#    6230 ):
# ...
